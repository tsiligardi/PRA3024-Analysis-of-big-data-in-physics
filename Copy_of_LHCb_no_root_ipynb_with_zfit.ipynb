# %% [markdown]
# <a href="https://colab.research.google.com/github/tsiligardi/PRA3024-Analysis-of-big-data-in-physics/blob/main/Copy_of_LHCb_no_root_ipynb_with_zfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **File handaling**<br>
# Install all the libraries needed for the code

# %%
# !pip install uproot awkward lz4 xxhash
# !pip install zfit
# !pip install mplhep
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: uproot in /usr/local/lib/python3.8/dist-packages (4.3.7)
# Requirement already satisfied: awkward in /usr/local/lib/python3.8/dist-packages (2.0.8)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.8/dist-packages (4.3.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from uproot) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from uproot) (1.22.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from awkward) (5.12.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from awkward) (4.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from awkward) (23.0)
# Requirement already satisfied: awkward-cpp==9 in /usr/local/lib/python3.8/dist-packages (from awkward) (9)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->awkward) (3.14.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: zfit in /usr/local/lib/python3.8/dist-packages (0.11.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.8/dist-packages (from zfit) (0.4.6)
# Requirement already satisfied: texttable in /usr/local/lib/python3.8/dist-packages (from zfit) (1.6.7)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from zfit) (1.10.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from zfit) (3.2.0)
# Requirement already satisfied: uhi in /usr/local/lib/python3.8/dist-packages (from zfit) (0.3.3)
# Requirement already satisfied: hist in /usr/local/lib/python3.8/dist-packages (from zfit) (2.6.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from zfit) (1.22.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.8/dist-packages (from zfit) (6.7.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.8/dist-packages (from zfit) (1.2.13)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from zfit) (0.8.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from zfit) (1.3.5)
# Requirement already satisfied: iminuit>=2.3 in /usr/local/lib/python3.8/dist-packages (from zfit) (2.20.0)
# Requirement already satisfied: jacobi in /usr/local/lib/python3.8/dist-packages (from zfit) (0.8.1)
# Requirement already satisfied: tensorflow<2.12,>=2.10 in /usr/local/lib/python3.8/dist-packages (from zfit) (2.11.0)
# Requirement already satisfied: colored in /usr/local/lib/python3.8/dist-packages (from zfit) (1.4.4)
# Requirement already satisfied: uproot<5,>=4 in /usr/local/lib/python3.8/dist-packages (from zfit) (4.3.7)
# Requirement already satisfied: dotmap in /usr/local/lib/python3.8/dist-packages (from zfit) (1.3.30)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.8/dist-packages (from zfit) (1.7.3)
# Requirement already satisfied: tf-quant-finance>=v0.0.1-dev24 in /usr/local/lib/python3.8/dist-packages (from zfit) (0.0.1.dev34)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.8/dist-packages (from zfit) (0.19.0)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.8/dist-packages (from zfit) (4.1.0)
# Requirement already satisfied: zfit-interface in /usr/local/lib/python3.8/dist-packages (from zfit) (0.0.3)
# Requirement already satisfied: boost-histogram in /usr/local/lib/python3.8/dist-packages (from zfit) (1.3.2)
# Requirement already satisfied: tensorflow-probability<0.20,>=0.18 in /usr/local/lib/python3.8/dist-packages (from zfit) (0.19.0)
# Requirement already satisfied: numdifftools in /usr/local/lib/python3.8/dist-packages (from zfit) (0.9.41)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (1.15.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (2.11.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (0.30.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (1.51.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (4.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (23.1.21)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (3.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (15.0.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (57.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (1.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (23.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.12,>=2.10->zfit) (2.11.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability<0.20,>=0.18->zfit) (0.1.8)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability<0.20,>=0.18->zfit) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability<0.20,>=0.18->zfit) (2.2.1)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.8/dist-packages (from tf-quant-finance>=v0.0.1-dev24->zfit) (22.2.0)
# Requirement already satisfied: histoprint>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from hist->zfit) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->zfit) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->zfit) (2022.7.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons->zfit) (2.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow<2.12,>=2.10->zfit) (0.38.4)
# Requirement already satisfied: click>=7.0.0 in /usr/local/lib/python3.8/dist-packages (from histoprint>=2.2.0->hist->zfit) (7.1.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (2.16.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (3.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<2.12,>=2.10->zfit) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mplhep in /usr/local/lib/python3.8/dist-packages (0.3.26)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.8/dist-packages (from mplhep) (3.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from mplhep) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from mplhep) (23.0)
# Requirement already satisfied: uhi>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from mplhep) (0.3.3)
# Requirement already satisfied: mplhep-data in /usr/local/lib/python3.8/dist-packages (from mplhep) (0.0.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->mplhep) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->mplhep) (1.15.0)

# %%
import uproot
f=uproot.open ("/content/drive/MyDrive/B2HHH_MagnetDown.root")
f.keys()
# Out:
# ['DecayTree;1']

# %%
from numpy import *
import matplotlib
import matplotlib.pyplot as plt

# %%
tree=f["DecayTree"].arrays(library="np")

# %% [markdown]
# **Defining classes and useful functions**<br>
# In this cell, I defined a class and some functions to avoid repetitions in the code, in particular
# <ul>
# <li> The class Daughter, which creates a daughter particle given the tree and the number (1,2, or 3), retrieving information about its momentum on the three components, the probabilities of being a kaon or a pion, calculating its total momentum. In addition, it has also a method to calculate the total energy of the particle. Although this may be an unusual approach, in my opinion, it simplifies the readability of the code and the accessibility of the information
# <li> A function to create three daughter particles given the tree
# <li> A function to calculate the total momentum of the mother and a function to calculate its mass
# <li> A function to plot the fitting of the model
# <li> A function to calculate the asymmetry and one for its uncertainty
#
#
# </ul>

# %%
#defining useful classes and functions
class Daughter:
  def __init__(self, tree, number):
    self.PX=tree["H{}_PX".format(number)]
    self.PY=tree["H{}_PY".format(number)]
    self.PZ=tree["H{}_PZ".format(number)]
    self.PTOT=sqrt(square(self.PX)+square(self.PY)+square(self.PZ))#total momentum of the daughter particle
    self.ProbK=tree["H{}_ProbK".format(number)]
    self.ProbPi=tree["H{}_ProbPi".format(number)]
    
  def getTotalEnergy(self, mass):
    return  sqrt(square(self.PTOT)+mass**2)#total energy of the particle

def getDaughterParticles(tree):
  daughters=[]
  for i in range(1,4):
    daughters.append(Daughter(tree,i))
  return daughters


def totalMomentumMother(H1,H2,H3):
  return sqrt(square(H1.PX+H2.PX+H3.PX)+square(H1.PY+H2.PY+H3.PY)+square(H1.PZ+H2.PZ+H3.PZ))

def massMother(H1,H2,H3,mass):
  return sqrt(square(H1.getTotalEnergy(mass)+H2.getTotalEnergy(mass)+H3.getTotalEnergy(mass))-square(totalMomentumMother(H1,H2,H3)))

def getModel(model,data,bins=100,title=None):# inspired from https://www.youtube.com/watch?v=YDW-XxrSbns:
  #fitting
  nll = zfit.loss.ExtendedUnbinnedNLL(model, data)
  minimizer = zfit.minimize.Minuit()
  result = minimizer.minimize(nll)
  print(result)
  #plotting
  lower, upper = data.data_range.limit1d
  counts, bin_edges = histogram(data.to_pandas(), bins=bins)
  plt.figure(figsize=(10,6))
  mplhep.histplot(counts, bins=bin_edges, histtype="errorbar", yerr=True, label="Data", color="black")
  binwidth = diff(bin_edges)[0]
  x = linspace(lower, upper, num=1000)
  y = model.ext_pdf(x) * binwidth
  plt.plot(x,y,label="model",color="blue")
  for mod, lab, col  in zip(model.get_models(),["signal","background"],["red","green"]):
    y_m=mod.ext_pdf(x) * binwidth
    plt.plot(x,y_m,label=lab,color=col,ls="--")
  plt.legend(loc="upper right")
  if title:
    plt.title(title)
  plt.show()
  return result.params



def asymmetry(Nplus, Nminus):
  return (Nminus-Nplus)/(Nminus+Nplus)

def deviation(Nplus, Nminus):
  return sqrt((1-asymmetry(Nplus, Nminus)**2)/(Nminus+Nplus))

# %%
#creating the istances for the three daughter particles
H1,H2,H3=getDaughterParticles(tree)

# %%
#plotting the hystogram
plt.hist(H1.PTOT,300,(0,300000),histtype='step',label='h1');
plt.hist(H2.PTOT,300,(0,300000),histtype='step',label='h2'); 
plt.hist(H3.PTOT,300,(0,300000),histtype='step',label='h3');  #the semicolon avoid printing the all array

plt.legend(loc='upper right');
plt.title("Momentum of the three daugther particles");
plt.xlabel('Momentum [$MeV/c^2$]');
plt.ylabel('Number of events');
plt.grid();

# %%
#Calculating the total momentum of the mother 
mother_ptot=totalMomentumMother(H1,H2,H3)


plt.hist(mother_ptot,300,(0,300000),histtype='step');

plt.title("total Momentum of the B meson");
plt.xlabel('Momentum [$MeV/c^2$]');
plt.ylabel('Number of events');
plt.grid();

# %%
#total mass of the mother
massK=493.677
mass_mother=massMother(H1,H2,H3,massK)

plt.hist(mass_mother,300,(4500,6000),histtype='step');

plt.title("Mass of the B meson");
plt.xlabel('Mass [$MeV/c^2$]');
plt.ylabel('Number of events');
plt.grid();

#Does this match what we would expect from theory?

# %% [markdown]
# According to Wikipedia (https://en.wikipedia.org/wiki/B_meson), the mass for B meson is $5279.34\  MeV/c^2$. The histogram has three peaks:
# <ul>
# <li> The highest around $5000\  MeV/c^2$
# <li> A second one between $5200\  MeV/c^2$ and $5400\  MeV/c^2$ (which correspond to the theoretical mass of B mesons)
# <li> A third one around $5400\  MeV/c^2$
# </ul>
# Considering that no filter has been applied yet and, therefore, there are also data about particles that are not B meson, the results seem reasonable.

# %%
#Make plots of H1/H2/H3 _ProbK on one plot
plt.hist(H1.ProbK,300,(0,1),histtype='step',label='Kh1');
plt.hist(H2.ProbK,300,(0,1),histtype='step',label='Kh2');
plt.hist(H3.ProbK,300,(0,1),histtype='step',label='Kh3');
plt.title("Probability of H1, H2, H3 being a kaon");
plt.xlabel('Probability');
plt.ylabel('Number of events');
plt.legend(loc='upper right');
plt.grid();

# %%
#Make plots of H1/H2/H3 _ProbPi on one plot
plt.hist(H1.ProbPi,300,(0,1),histtype='step',label='Pi H1');
plt.hist(H3.ProbPi,300,(0,1),histtype='step',label='Pi H3');
plt.hist(H2.ProbPi,300,(0,1),histtype='step',label='Pi H2');
plt.legend(loc='upper center');
plt.title("Probability of H1, H2, H3 being a Pion");
plt.xlabel('Probability');
plt.ylabel('Number of events');
plt.grid();

# %%
#make a plot of the B_VertexChi2
plt.hist(tree["B_VertexChi2"],300,(0,15),histtype='step',label='B vertex ki');

plt.xlabel('Chi2');
plt.ylabel('Number of events');
plt.title("Plot of Vertex Chi2 for the B Meson");
plt.grid();

# %% [markdown]
# Based on the previous plots, it was decided to keep the data relative to those particles whose probability to be a Kion is more than 50%, that are not muon and whose probability to be a pion is less tha 0.15%

# %%
#Making the selction
selection="(H1_ProbK>0.5) & (H2_ProbK>0.5) & (H3_ProbK>0.5) & (H1_ProbPi<0.15) & (H1_isMuon==0) & (H2_isMuon==0) &(H3_isMuon==0)& (H2_ProbPi<0.15) & (H3_ProbPi<0.15)"
cutTree=f["DecayTree"].arrays(library="np",cut=selection)

# %%
H1_cut,H2_cut,H3_cut=getDaughterParticles(cutTree)


mass_mother_cut=massMother(H1_cut,H2_cut,H3_cut,massK)

plt.hist(mass_mother,300,(4000,6000),histtype='step',label="Mass of the B \n meson before cuts");
plt.hist(mass_mother_cut,300,(3000,7000),histtype='step',label="Mass of the \n B meson after cuts");
plt.legend(loc='upper left');
plt.title("Mass of the B meson before and after cuts");
plt.xlabel('Momentum [$MeV/c^2$]');
plt.ylabel('Number of events');
plt.grid();

# %%
#mother cut alone

plt.hist(mass_mother_cut,300,(5000,6500),histtype='step');
plt.title("Mass of the B meson after cuts");
plt.xlabel('Momentum [$MeV/c^2$]');
plt.ylabel('Number of events');
plt.grid()

#What do you notice about your histogram now?

# %% [markdown]
# The histogram is now way narrower, with the peak between $5200\  MeV/c^2$ and $5400\  MeV/c^2$ (which correspond to the mass of the B mesons). However, the number of events is greatly reduced.

# %%
import zfit
import iminuit
import mplhep
# Out:
# /usr/local/lib/python3.8/dist-packages/zfit/__init__.py:62: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %%
mass=zfit.Space("mass",limits=(5200,5800))
data = zfit.Data.from_numpy(obs=mass, array=mass_mother_cut)#selecting the data in that range
data_np = zfit.run(data.value()[:, 0])

#signal
gauss_mean=zfit.Parameter("mean",5300,5200,5900)
gauss_width=zfit.Parameter("sd",40,0,7000)
gauss_norm=zfit.Parameter("gauss_yield",data_np.shape[0]/30, 0, data_np.shape[0]*3)


#background
lam=zfit.Parameter("lambda",-0.02, -2, +2)
exp_norm=zfit.Parameter("background_yield",data_np.shape[0]/30, 0, data_np.shape[0]*2)

# %%
#creating the model
signal=zfit.pdf.Gauss(obs=mass, mu=gauss_mean, sigma=gauss_width).create_extended(gauss_norm)
bckg=zfit.pdf.Exponential(lam, obs=mass).create_extended(exp_norm)

model=zfit.pdf.SumPDF([signal,bckg])

#getting the model
result=getModel(model,data,title="mass")
# Out:
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.functor.SumPDF'>  params=[Composed_autoparam_1, Composed_autoparam_2]] data=[<zfit.core.data.Data object at 0x7fc0481c8b20>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤═════════════╕
# │ valid   │ converged   │ param at limit   │ edm     │ min value   │
# ╞═════════╪═════════════╪══════════════════╪═════════╪═════════════╡
# │ True    │ True        │ False            │ 8.7e-05 │ -14927.33   │
# ╘═════════╧═════════════╧══════════════════╧═════════╧═════════════╛
#
# Parameters
# name                value  (rounded)    at limit
# ----------------  ------------------  ----------
# gauss_yield                  5200.88       False
# background_yield             985.898       False
# mean                         5284.03       False
# sd                           17.5381       False
# lambda                   -0.00185162       False

# %%
print("signal yield: ",result[gauss_norm]["value"],"\nbackground yield: ",result[exp_norm]["value"])
# Out:
# signal yield:  5200.880731616843
# background yield:  985.8981888738075

# %% [markdown]
# **Counting**

# %%
totalCharge= "H1_Charge+H2_Charge+H3_Charge"
#filtering by charge
B_minus=f["DecayTree"].arrays(cut="({}==-1)&{}".format(totalCharge,selection), library="np")#with numpy gives some errors
B_plus=f["DecayTree"].arrays(cut="({}==1)&{}".format(totalCharge,selection), library="np")

# %%
#Model B_minus
H1_Bminus,H2_Bminus,H3_Bminus=getDaughterParticles(B_minus)
mass_mother_Bminus=massMother(H1_Bminus,H2_Bminus,H3_Bminus,massK)

data_B_minus=zfit.Data.from_numpy(obs=mass, array=mass_mother_Bminus)#selecting the data in that range

N_minus=getModel(model,data_B_minus)[gauss_norm]["value"]
# Out:
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.functor.SumPDF'>  params=[Composed_autoparam_1, Composed_autoparam_2]] data=[<zfit.core.data.Data object at 0x7fbf500e0f40>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤═════════════╕
# │ valid   │ converged   │ param at limit   │ edm     │ min value   │
# ╞═════════╪═════════════╪══════════════════╪═════════╪═════════════╡
# │ True    │ True        │ False            │ 0.00033 │ -66.8319    │
# ╘═════════╧═════════════╧══════════════════╧═════════╧═════════════╛
#
# Parameters
# name                value  (rounded)    at limit
# ----------------  ------------------  ----------
# gauss_yield                  2444.32       False
# background_yield             497.655       False
# mean                         5284.92       False
# sd                           17.7271       False
# lambda                    -0.0017525       False

# %%
#Model B_plus
H1_Bplus,H2_Bplus,H3_Bplus=getDaughterParticles(B_plus)
mass_mother_Bplus=massMother(H1_Bplus,H2_Bplus,H3_Bplus,massK)

data_B_plus=zfit.Data.from_numpy(obs=mass, array=mass_mother_Bplus)

N_plus=getModel(model,data_B_plus)[gauss_norm]["value"]
# Out:
# FitResult of
# <ExtendedUnbinnedNLL model=[<zfit.<class 'zfit.models.functor.SumPDF'>  params=[Composed_autoparam_1, Composed_autoparam_2]] data=[<zfit.core.data.Data object at 0x7fc06e199d60>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤═════════════╕
# │ valid   │ converged   │ param at limit   │ edm     │ min value   │
# ╞═════════╪═════════════╪══════════════════╪═════════╪═════════════╡
# │ True    │ True        │ False            │ 2.4e-06 │ 964.5772    │
# ╘═════════╧═════════════╧══════════════════╧═════════╧═════════════╛
#
# Parameters
# name                value  (rounded)    at limit
# ----------------  ------------------  ----------
# gauss_yield                  2755.06       False
# background_yield              488.93       False
# mean                         5283.26       False
# sd                           17.3221       False
# lambda                    -0.0019597       False

# %%
print("asymmetry: ",asymmetry(Nminus=N_minus,Nplus=N_plus),"\nuncertainty:",deviation(Nminus=N_minus,Nplus=N_plus))
# Out:
# asymmetry:  -0.05976545294189644
# uncertainty: 0.013843551309596391

# %% [markdown]
# The results shows indeed an asimmetry between the B+ meson and B-. This prevalence of the matter over anti-matter is why we (and the entire universe) exist.
